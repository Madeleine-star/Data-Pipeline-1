# %% [markdown]
# Ressource: https://kb.aspose.com/fr/pdf/python/how-to-convert-xsl-fo-to-pdf-using-python/

# %%
#aspose-pdf installation
pip install aspose-pdf
# Out:
# ...
#    ---------------------------------------- 0.0/89.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/89.8 MB 330.3 kB/s eta 0:04:32
#    ---------------------------------------- 0.1/89.8 MB 656.4 kB/s eta 0:02:17
#    ---------------------------------------- 0.2/89.8 MB 1.8 MB/s eta 0:00:50
#     --------------------------------------- 1.2/89.8 MB 7.0 MB/s eta 0:00:13
#    - -------------------------------------- 2.8/89.8 MB 12.5 MB/s eta 0:00:07
#    - -------------------------------------- 4.4/89.8 MB 16.6 MB/s eta 0:00:06
#    -- ------------------------------------- 6.2/89.8 MB 19.6 MB/s eta 0:00:05
#    --- ------------------------------------ 7.9/89.8 MB 21.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 9.7/89.8 MB 23.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 11.4/89.8 MB 36.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 13.1/89.8 MB 36.4 MB/s eta 0:00:03
# ...

# %%
#import the library
import aspose.pdf as pdf

# %%
InputXSLFODocument = pdf.Document("C:/Users/marie/Documents/DSTI_Cours/Data_Pipeline/Exam_project/Readme-Pipeline/MW/RecipeBox_DB/Xslt_to_fo_file/ingredient_list.fo", pdf.XslFoLoadOptions())

# %%
InputXSLFODocument.save("ingredient_list.pdf")
